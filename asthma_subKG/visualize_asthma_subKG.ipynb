# %%
import networkx as nx
from pyvis.network import Network
import json

def create_enhanced_kg_visualization(kg_data, output_file="enhanced_kg_visualization.html"):
    """
    Create an interactive visualization of the enhanced knowledge graph
    """
    # Create a new network
    net = Network(height="750px", width="100%", bgcolor="#ffffff", font_color="black")
    net.force_atlas_2based()
    
    # Track added nodes to avoid duplicates
    added_nodes = set()
    
    def analyze_entity_types(kg_data):
        """
        Analyze all entity types present in the knowledge graph and create a color scheme
        """
        entity_types = {}
        type_counts = {}
        
        # Extract all instance_of (P31) and subclass_of (P279) relations
        for triple in kg_data['subgraph']['triples']:
            if triple['predicate']['id'] in ['P31', 'P279']:
                target_id = triple['target']['id']
                source_id = triple['source']['id']
                
                # Get the type label from metadata
                target_metadata = kg_data['subgraph']['entities'].get(target_id, {}).get('metadata', {})
                type_label = target_metadata.get('label', target_id)
                
                if target_id not in entity_types:
                    entity_types[target_id] = type_label
                    type_counts[target_id] = 0
                type_counts[target_id] += 1

        # Sort types by frequency
        sorted_types = sorted(type_counts.items(), key=lambda x: x[1], reverse=True)
        
        # Define a broader color palette
        colors = [
            '#ff6b6b',  # Red
            '#4ecdc4',  # Turquoise
            '#45b7d1',  # Blue
            '#96ceb4',  # Soft Green
            '#88d8b0',  # Light Green
            '#ffeead',  # Light Yellow
            '#ff9f80',  # Coral
            '#d4a5a5',  # Dusty Rose
            '#82b74b',  # Green
            '#9b59b6',  # Purple
            '#3498db',  # Blue
            '#e74c3c',  # Red
            '#2ecc71',  # Green
            '#f1c40f',  # Yellow
            '#1abc9c',  # Turquoise
            '#e67e22',  # Orange
            '#95a5a6',  # Gray
            '#16a085',  # Dark Turquoise
            '#d35400',  # Dark Orange
            '#c0392b',  # Dark Red
            '#a3a3a3',  # Light Gray
            '#7f8c8d'   # Dark Gray
        ]
        
        # Create color mapping
        type_colors = {'default': '#7f7f7f'}
        print("\nEntity Types in Knowledge Graph:")
        for i, (type_id, count) in enumerate(sorted_types):
            color_idx = min(i, len(colors) - 1)
            type_colors[type_id] = colors[color_idx]
            print(f"{entity_types[type_id]} ({type_id}): {count} instances -> {colors[color_idx]}")
        
        return type_colors

    # Generate color scheme based on actual data
    type_colors = analyze_entity_types(kg_data)

    def get_entity_type(entity_data):
        """Extract entity type from enhanced entity data"""
        if entity_data and 'data' in entity_data and 'claims' in entity_data['data']:
            instance_claims = entity_data['data'].get('claims', {}).get('P31', [])
            if instance_claims:
                return instance_claims[0].get('mainsnak', {}).get('datavalue', {}).get('value', {}).get('id')
        return 'default'

    def create_tooltip(entity_data):
        """Create tooltip with enhanced entity information"""
        if not entity_data:
            return "No information available"
            
        tooltip = "<div style='max-width: 300px;'>"
        
        # Get metadata from enhanced structure
        metadata = entity_data.get('metadata', {})
        label = metadata.get('label', 'Unknown')
        description = metadata.get('description', '')
        
        tooltip += f"<strong>{label}</strong>"
        if description:
            tooltip += f"<br><em>{description}</em>"
            
        # Add entity type information
        if 'data' in entity_data and 'claims' in entity_data['data']:
            type_claims = entity_data['data']['claims'].get('P31', [])
            subclass_claims = entity_data['data']['claims'].get('P279', [])
            
            if type_claims or subclass_claims:
                tooltip += "<br><br><strong>Classifications:</strong>"
                
            # Add instance of (P31) relations
            for claim in type_claims:
                if 'mainsnak' in claim and 'datavalue' in claim['mainsnak']:
                    type_id = claim['mainsnak']['datavalue']['value']['id']
                    type_entity = kg_data['subgraph']['entities'].get(type_id, {})
                    type_label = type_entity.get('metadata', {}).get('label', type_id)
                    tooltip += f"<br>• Type: {type_label}"
                    
            # Add subclass of (P279) relations
            for claim in subclass_claims:
                if 'mainsnak' in claim and 'datavalue' in claim['mainsnak']:
                    superclass_id = claim['mainsnak']['datavalue']['value']['id']
                    superclass_entity = kg_data['subgraph']['entities'].get(superclass_id, {})
                    superclass_label = superclass_entity.get('metadata', {}).get('label', superclass_id)
                    tooltip += f"<br>• Subclass of: {superclass_label}"
            
        # Add qualifiers if available
        if 'data' in entity_data and 'claims' in entity_data['data']:
            properties = []
            for prop_id, claims in entity_data['data']['claims'].items():
                if prop_id in kg_data['metadata'].get('medical_properties', {}):
                    prop_name = kg_data['metadata']['medical_properties'][prop_id]
                    properties.append(f"<br>• {prop_name}")
            if properties:
                tooltip += "<br><br><strong>Properties:</strong>"
                tooltip += ''.join(properties)
                
        tooltip += "</div>"
        return tooltip

    # Filter to get 3-hop neighborhood of asthma
    asthma_id = 'Q199804'
    nodes_in_scope = {asthma_id}
    current_nodes = {asthma_id}
    
    # Get triples in correct format from enhanced structure
    triples = [(t['source']['id'], t['predicate']['id'], t['target']['id']) 
              for t in kg_data['subgraph']['triples']]
    
    # Perform 3-hop expansion
    for _ in range(3):
        next_nodes = set()
        for triple in triples:
            subject, _, object_id = triple
            if subject in current_nodes:
                next_nodes.add(object_id)
            if object_id in current_nodes:
                next_nodes.add(subject)
        current_nodes = next_nodes
        nodes_in_scope.update(next_nodes)

    # Filter triples to only those involving nodes in scope
    filtered_triples = [
        triple for triple in kg_data['subgraph']['triples']
        if triple['source']['id'] in nodes_in_scope and 
        triple['target']['id'] in nodes_in_scope
    ]

    # Process nodes
    entities = kg_data['subgraph']['entities']
    for triple in filtered_triples:
        for entity_type in ['source', 'target']:
            entity_id = triple[entity_type]['id']
            if entity_id not in added_nodes:
                entity_data = entities.get(entity_id, {})
                entity_type_id = get_entity_type(entity_data)
                
                # Special styling for asthma node
                if entity_id == asthma_id:
                    net.add_node(
                        entity_id,
                        label="ASTHMA",
                        title=create_tooltip(entity_data),
                        color='#ff0000',
                        size=100,
                        borderWidth=4,
                        borderWidthSelected=8,
                        font={'size': 20, 'color': 'black', 'face': 'arial', 'bold': True}
                    )
                else:
                    # Regular node
                    label = entity_data.get('metadata', {}).get('label', entity_id)
                    net.add_node(
                        entity_id,
                        label=label,
                        title=create_tooltip(entity_data),
                        color=type_colors.get(entity_type_id, type_colors['default']),
                        size=30
                    )
                added_nodes.add(entity_id)

        # Add edge with enhanced information
        predicate = triple['predicate']
        property_labels = {
            'P780': 'has symptom',
            'P828': 'has cause',
            'P927': 'located in',
            'P2176': 'treated by',
            'P1050': 'medical condition',
            'P2175': 'treats',
            'P31': 'is a',
            'P279': 'subclass of'
        }
        
        edge_label = property_labels.get(predicate['id'], predicate['label'])
        edge_color = '#7c7c7c'
        
        if predicate['id'] in ['P780', 'P828']:  # symptoms and causes
            edge_color = '#ff9999'
        elif predicate['id'] in ['P2176', 'P2175']:  # treatments
            edge_color = '#99ccff'
        elif predicate['id'] in ['P31', 'P279']:  # classification
            edge_color = '#c2c2c2'
            
        # Create edge tooltip with qualifiers
        edge_tooltip = f"Relationship: {edge_label}"
        if triple.get('qualifiers'):
            edge_tooltip += "\nQualifiers:"
            for qualifier in triple['qualifiers']:
                edge_tooltip += f"\n• {qualifier['property']}: {qualifier['value']}"
        
        net.add_edge(
            triple['source']['id'],
            triple['target']['id'],
            label=edge_label,
            title=edge_tooltip,
            color=edge_color,
            arrows={'to': {'enabled': True}}
        )

    # Configure physics settings
    net.set_options("""
    var options = {
        "physics": {
            "forceAtlas2Based": {
                "gravitationalConstant": -50,
                "centralGravity": 0.01,
                "springLength": 200,
                "springConstant": 0.08
            },
            "maxVelocity": 50,
            "solver": "forceAtlas2Based",
            "timestep": 0.35,
            "stabilization": {"iterations": 150}
        },
        "edges": {
            "color": {"inherit": false},
            "smooth": {"type": "continuous"},
            "length": 200,
            "font": {
                "size": 10
            }
        },
        "nodes": {
            "font": {
                "size": 12,
                "face": "arial"
            },
            "borderWidth": 2,
            "borderWidthSelected": 4
        }
    }
    """)
    
    # Save the visualization
    net.save_graph(output_file)
    print(f"Visualization saved to {output_file}")
    print(f"Number of nodes in visualization: {len(added_nodes)}")
    print(f"Number of edges in visualization: {len(filtered_triples)}")

def main():
    # Load the enhanced knowledge graph
    with open('enhanced_copd_kg_4hops.json', 'r') as f:
        kg_data = json.load(f)
        
    # Create visualization
    create_enhanced_kg_visualization(
        kg_data=kg_data,
        output_file="enhanced_asthma_knowledge_graph.html"
    )

if __name__ == "__main__":
    main()
# Out:
# Entity Types in Knowledge Graph:
# gene (Q7187): 697 instances -> #ff6b6b
# protein-coding gene (Q20747295): 686 instances -> #4ecdc4
# type of chemical entity (Q113145171): 274 instances -> #45b7d1
# chemical compound (Q11173): 140 instances -> #96ceb4
# class of disease (Q112193867): 118 instances -> #88d8b0
# disease (Q12136): 81 instances -> #ffeead
# symptom or sign (Q112965645): 59 instances -> #ff9f80
# medication (Q12140): 44 instances -> #d4a5a5
# group of stereoisomers (Q59199015): 38 instances -> #82b74b
# clinical sign (Q1441305): 31 instances -> #9b59b6
# symptom (Q169872): 26 instances -> #3498db
# mixture (Q169336): 24 instances -> #e74c3c
# Q193430 (Q193430): 23 instances -> #2ecc71
# Q79529 (Q79529): 21 instances -> #f1c40f
# medical specialty (Q930752): 17 instances -> #1abc9c
# Q427087 (Q427087): 15 instances -> #e67e22
# academic discipline (Q11862829): 14 instances -> #95a5a6
# metaclass (Q19478619): 14 instances -> #16a085
# rare disease (Q929833): 13 instances -> #d35400
# physiological condition (Q7189713): 10 instances -> #c0392b
# health problem (Q2057971): 9 instances -> #a3a3a3
# second-order class (Q24017414): 9 instances -> #7f8c8d
# carboxylic acid (Q134856): 9 instances -> #7f8c8d
# medical finding (Q639907): 9 instances -> #7f8c8d
# type (Q21146257): 9 instances -> #7f8c8d
# Q70702 (Q70702): 9 instances -> #7f8c8d
# respiratory signs and symptoms (Q42183538): 8 instances -> #7f8c8d
# class (Q16889133): 8 instances -> #7f8c8d
# syndrome (Q179630): 8 instances -> #7f8c8d
# structural class of chemical entities (Q47154513): 8 instances -> #7f8c8d
# Q35456 (Q35456): 8 instances -> #7f8c8d
# non-steroidal anti-inflammatory drug (Q188724): 8 instances -> #7f8c8d
# lung disease (Q3392853): 7 instances -> #7f8c8d
# variable-order class (Q23958852): 7 instances -> #7f8c8d
# symptom type (Q130753312): 7 instances -> #7f8c8d
# medicine (Q11190): 7 instances -> #7f8c8d
# concept (Q151885): 6 instances -> #7f8c8d
# autoimmune disease (Q8084905): 6 instances -> #7f8c8d
# designated intractable/rare disease (Q42303753): 6 instances -> #7f8c8d
# skin disease (Q949302): 6 instances -> #7f8c8d
# developmental defect during embryogenesis (Q55788864): 6 instances -> #7f8c8d
# infectious disease (Q18123741): 6 instances -> #7f8c8d
# Q277338 (Q277338): 6 instances -> #7f8c8d
# Q665843 (Q665843): 6 instances -> #7f8c8d
# Q49858617 (Q49858617): 6 instances -> #7f8c8d
# morphinan alkaloid (Q4303473): 5 instances -> #7f8c8d
# gastrointestinal system disease (Q2300099): 5 instances -> #7f8c8d
# cause of death (Q1931388): 5 instances -> #7f8c8d
# activity (Q1914636): 5 instances -> #7f8c8d
# Q109195877 (Q109195877): 5 instances -> #7f8c8d
# Q355518 (Q355518): 5 instances -> #7f8c8d
# Q31836626 (Q31836626): 5 instances -> #7f8c8d
# Q3508753 (Q3508753): 5 instances -> #7f8c8d
# Q271021 (Q271021): 5 instances -> #7f8c8d
# biological process (Q2996394): 4 instances -> #7f8c8d
# geographical feature (Q618123): 4 instances -> #7f8c8d
# pain (Q81938): 4 instances -> #7f8c8d
# connective tissue disease (Q1779300): 4 instances -> #7f8c8d
# vascular disease (Q1266890): 4 instances -> #7f8c8d
# group or class of chemical substances (Q17339814): 4 instances -> #7f8c8d
# clinical finding (Q28807560): 4 instances -> #7f8c8d
# Q18557436 (Q18557436): 4 instances -> #7f8c8d
# Q113129019 (Q113129019): 4 instances -> #7f8c8d
# Q389735 (Q389735): 4 instances -> #7f8c8d
# Q2585617 (Q2585617): 4 instances -> #7f8c8d
# Q72070508 (Q72070508): 4 instances -> #7f8c8d
# Q102187407 (Q102187407): 4 instances -> #7f8c8d
# Q4214615 (Q4214615): 4 instances -> #7f8c8d
# internal medicine (Q11180): 3 instances -> #7f8c8d
# pediatrics (Q123028): 3 instances -> #7f8c8d
# first-order class (Q104086571): 3 instances -> #7f8c8d
# abnormal breathing (Q2056816): 3 instances -> #7f8c8d
# health specialty (Q44597158): 3 instances -> #7f8c8d
# field of study (Q1047113): 3 instances -> #7f8c8d
# knowledge classification (Q110402867): 3 instances -> #7f8c8d
# lower respiratory tract disease (Q18553224): 3 instances -> #7f8c8d
# health risk (Q87075524): 3 instances -> #7f8c8d
# property (Q937228): 3 instances -> #7f8c8d
# arthritis (Q170990): 3 instances -> #7f8c8d
# vasculitis (Q644318): 3 instances -> #7f8c8d
# fixed-order class (Q23959932): 3 instances -> #7f8c8d
# third-order class (Q24017465): 3 instances -> #7f8c8d
# Australian pregnancy category (Q28123510): 3 instances -> #7f8c8d
# human activity (Q61788060): 3 instances -> #7f8c8d
# respiratory disease (Q3286546): 3 instances -> #7f8c8d
# mode of transmission (Q1662340): 3 instances -> #7f8c8d
# geographic entity (Q27096213): 3 instances -> #7f8c8d
# Q843601 (Q843601): 3 instances -> #7f8c8d
# Q422687 (Q422687): 3 instances -> #7f8c8d
# Q3505845 (Q3505845): 3 instances -> #7f8c8d
# Q7048977 (Q7048977): 3 instances -> #7f8c8d
# Q179661 (Q179661): 3 instances -> #7f8c8d
# Q4116663 (Q4116663): 3 instances -> #7f8c8d
# Q57842052 (Q57842052): 3 instances -> #7f8c8d
# Q708176 (Q708176): 3 instances -> #7f8c8d
# Q3843811 (Q3843811): 3 instances -> #7f8c8d
# Q49848922 (Q49848922): 3 instances -> #7f8c8d
# Q102186671 (Q102186671): 3 instances -> #7f8c8d
# Q21112553 (Q21112553): 3 instances -> #7f8c8d
# Q102186864 (Q102186864): 3 instances -> #7f8c8d
# Q373822 (Q373822): 3 instances -> #7f8c8d
# Q2118866 (Q2118866): 3 instances -> #7f8c8d
# Q8054 (Q8054): 3 instances -> #7f8c8d
# Q71574018 (Q71574018): 3 instances -> #7f8c8d
# Q426549 (Q426549): 3 instances -> #7f8c8d
# Q584144 (Q584144): 3 instances -> #7f8c8d
# taxon (Q16521): 2 instances -> #7f8c8d
# Q103994247 (Q103994247): 2 instances -> #7f8c8d
# psychoactive drug use (Q110207349): 2 instances -> #7f8c8d
# feature type (Q12046615): 2 instances -> #7f8c8d
# type of process (Q116505632): 2 instances -> #7f8c8d
# occurrence (Q1190554): 2 instances -> #7f8c8d
# risk source (Q86923152): 2 instances -> #7f8c8d
# pneumonitis (Q1284347): 2 instances -> #7f8c8d
# autosomal dominant disease (Q18553439): 2 instances -> #7f8c8d
# neurodevelopmental disorder (Q3450985): 2 instances -> #7f8c8d
# autoimmune disease of musculoskeletal system (Q18553609): 2 instances -> #7f8c8d
# Q55788696 (Q55788696): 2 instances -> #7f8c8d
# rare genetic developmental defect during embryogenesis (Q55785846): 2 instances -> #7f8c8d
# dengue fever (Q30953): 2 instances -> #7f8c8d
# artery disease (Q18965518): 2 instances -> #7f8c8d
# esophageal disease (Q2912193): 2 instances -> #7f8c8d
# endocrine system disease (Q2661443): 2 instances -> #7f8c8d
# bronchospasm (Q279330): 2 instances -> #7f8c8d
# drug (Q8386): 2 instances -> #7f8c8d
# pharmaceutical product (Q28885102): 2 instances -> #7f8c8d
# US pregnancy category (Q28123509): 2 instances -> #7f8c8d
# chronic obstructive pulmonary disease (Q199804): 2 instances -> #7f8c8d
# use (Q1724915): 2 instances -> #7f8c8d
# pollution (Q58734): 2 instances -> #7f8c8d
# tertiary amine (Q72801119): 2 instances -> #7f8c8d
# infection (Q166231): 2 instances -> #7f8c8d
# direct transmission (Q15304504): 2 instances -> #7f8c8d
# geographic location (Q2221906): 2 instances -> #7f8c8d
# type of object (Q96251598): 2 instances -> #7f8c8d
# physical location (Q17334923): 2 instances -> #7f8c8d
# Q5962346 (Q5962346): 2 instances -> #7f8c8d
# Q112826905 (Q112826905): 2 instances -> #7f8c8d
# Q113129005 (Q113129005): 2 instances -> #7f8c8d
# Q483247 (Q483247): 2 instances -> #7f8c8d
# Q1293220 (Q1293220): 2 instances -> #7f8c8d
# Q844482 (Q844482): 2 instances -> #7f8c8d
# Q2438541 (Q2438541): 2 instances -> #7f8c8d
# Q28598684 (Q28598684): 2 instances -> #7f8c8d
# Q420 (Q420): 2 instances -> #7f8c8d
# inflammation (Q101991): 2 instances -> #7f8c8d
# Q54943763 (Q54943763): 2 instances -> #7f8c8d
# Q54932064 (Q54932064): 2 instances -> #7f8c8d
# Q177911 (Q177911): 2 instances -> #7f8c8d
# Q412205 (Q412205): 2 instances -> #7f8c8d
# DL-amphetamine (Q179452): 2 instances -> #7f8c8d
# Q3339235 (Q3339235): 2 instances -> #7f8c8d
# Q3087172 (Q3087172): 2 instances -> #7f8c8d
# Q3063847 (Q3063847): 2 instances -> #7f8c8d
# Q1969448 (Q1969448): 2 instances -> #7f8c8d
# Q30897648 (Q30897648): 2 instances -> #7f8c8d
# Q1475848 (Q1475848): 2 instances -> #7f8c8d
# Q47147773 (Q47147773): 2 instances -> #7f8c8d
# Q11344 (Q11344): 2 instances -> #7f8c8d
# Q112826975 (Q112826975): 2 instances -> #7f8c8d
# Q1088113 (Q1088113): 2 instances -> #7f8c8d
# Q3278145 (Q3278145): 2 instances -> #7f8c8d
# Q54926352 (Q54926352): 2 instances -> #7f8c8d
# Q99860490 (Q99860490): 2 instances -> #7f8c8d
# Q48143 (Q48143): 2 instances -> #7f8c8d
# Q102187434 (Q102187434): 2 instances -> #7f8c8d
# Q102186826 (Q102186826): 2 instances -> #7f8c8d
# Q421700 (Q421700): 2 instances -> #7f8c8d
# Q109330013 (Q109330013): 2 instances -> #7f8c8d
# Q462174 (Q462174): 2 instances -> #7f8c8d
# Q40821 (Q40821): 2 instances -> #7f8c8d
# Q18553400 (Q18553400): 2 instances -> #7f8c8d
# Q12078 (Q12078): 2 instances -> #7f8c8d
# Q516751 (Q516751): 2 instances -> #7f8c8d
# Q27163789 (Q27163789): 2 instances -> #7f8c8d
# Q81976571 (Q81976571): 2 instances -> #7f8c8d
# Q1057079 (Q1057079): 2 instances -> #7f8c8d
# Q3055380 (Q3055380): 2 instances -> #7f8c8d
# Q41014950 (Q41014950): 2 instances -> #7f8c8d
# abdominal pain (Q183425): 2 instances -> #7f8c8d
# chest pain (Q693058): 2 instances -> #7f8c8d
# Q19885597 (Q19885597): 2 instances -> #7f8c8d
# Q178859 (Q178859): 2 instances -> #7f8c8d
# Q127038678 (Q127038678): 2 instances -> #7f8c8d
# Q109653162 (Q109653162): 2 instances -> #7f8c8d
# smoking (Q662860): 2 instances -> #7f8c8d
# Q58833963 (Q58833963): 2 instances -> #7f8c8d
# Q727028 (Q727028): 2 instances -> #7f8c8d
# Q18558209 (Q18558209): 2 instances -> #7f8c8d
# Q102186813 (Q102186813): 2 instances -> #7f8c8d
# Q488383 (Q488383): 2 instances -> #7f8c8d
# obstructive lung disease (Q3508797): 1 instances -> #7f8c8d
# mountain (Q8502): 1 instances -> #7f8c8d
# Ambroxol (Q105124245): 1 instances -> #7f8c8d
# (R)-5-(2-(5,6-diethyl-2,3-dihydro-1H-inden-2-ylamino)-1-hydroxyethyl)-8-hydroxyquinolin-2(1H)-one (Q126676412): 1 instances -> #7f8c8d
# cation (Q326277): 1 instances -> #7f8c8d
# DL-carbocysteine (Q27258488): 1 instances -> #7f8c8d
# custom (Q251777): 1 instances -> #7f8c8d
# aerosol (Q104541): 1 instances -> #7f8c8d
# complex mixtures (Q66902062): 1 instances -> #7f8c8d
# continuous adventitious sound (Q43144085): 1 instances -> #7f8c8d
# group or class of organisms (Q21871294): 1 instances -> #7f8c8d
# elevation (Q106589819): 1 instances -> #7f8c8d
# natural geographic object (Q35145263): 1 instances -> #7f8c8d
# branch of science (Q2465832): 1 instances -> #7f8c8d
# racemate (Q467717): 1 instances -> #7f8c8d
# type of mixture of chemical entities (Q119892838): 1 instances -> #7f8c8d
# problem (Q621184): 1 instances -> #7f8c8d
# anomaly (Q567555): 1 instances -> #7f8c8d
# type of problem (Q130286945): 1 instances -> #7f8c8d
# biological phenomenon (Q64732777): 1 instances -> #7f8c8d
# physical process (Q17320256): 1 instances -> #7f8c8d
# end (Q12769393): 1 instances -> #7f8c8d
# sensation (Q3955369): 1 instances -> #7f8c8d
# Agents (Medicine) (Q2673269): 1 instances -> #7f8c8d
# type of gene (Q131679239): 1 instances -> #7f8c8d
# overnutrition (Q16956975): 1 instances -> #7f8c8d
# nucleic acid sequence (Q863908): 1 instances -> #7f8c8d
# biological region (Q50365914): 1 instances -> #7f8c8d
# biomolecular structure (Q15712714): 1 instances -> #7f8c8d
# alveolar lung disease (Q4737951): 1 instances -> #7f8c8d
# rare pulmonary disease (Q56013678): 1 instances -> #7f8c8d
# breast adenocarcinoma (Q18555946): 1 instances -> #7f8c8d
# marfanoid (Q6759035): 1 instances -> #7f8c8d
# rare disease with thoracic aortic aneurysm and aortic dissection (Q55786976): 1 instances -> #7f8c8d
# specific developmental disorder (Q7574983): 1 instances -> #7f8c8d
# hyperkinetic disorder (Q17028415): 1 instances -> #7f8c8d
# Q1815366 (Q1815366): 1 instances -> #7f8c8d
# disability (Q12131): 1 instances -> #7f8c8d
# neurodiversity (Q2915349): 1 instances -> #7f8c8d
# amyotrophic lateral sclerosis (Q206901): 1 instances -> #7f8c8d
# autoimmune skin disease (Q12504769): 1 instances -> #7f8c8d
# chronic condition (Q383126): 1 instances -> #7f8c8d
# collagen disease (Q1446169): 1 instances -> #7f8c8d
# Felty's syndrome (Q1404470): 1 instances -> #7f8c8d
# secondary glomerular disease (Q55788835): 1 instances -> #7f8c8d
# systemic diseases with anterior uveitis (Q55786944): 1 instances -> #7f8c8d
# systemic diseases with posterior uveitis (Q55786945): 1 instances -> #7f8c8d
# systemic diseases with panuveitis (Q55786946): 1 instances -> #7f8c8d
# autoinflammatory syndrome with skin involvement (Q55787013): 1 instances -> #7f8c8d
# vascular skin disease (Q18558156): 1 instances -> #7f8c8d
# unclassified autoinflammatory syndrome (Q55787622): 1 instances -> #7f8c8d
# predominantly large-vessel vasculitis (Q55785504): 1 instances -> #7f8c8d
# inflammatory and autoimmune disease with epilepsy (Q55785633): 1 instances -> #7f8c8d
# autoimmune disease of cardiovascular system (Q4826340): 1 instances -> #7f8c8d
# erythema (Q1166142): 1 instances -> #7f8c8d
# severe cutaneous adverse reactions (Q55632923): 1 instances -> #7f8c8d
# branchiootic syndrome (Q18966109): 1 instances -> #7f8c8d
# branchial arch or oral-acral syndrome (Q55785404): 1 instances -> #7f8c8d
# head and neck disease (Q55789477): 1 instances -> #7f8c8d
# autoimmune disease of gastrointestinal tract (Q18553608): 1 instances -> #7f8c8d
# gluten-related disorder (Q1367782): 1 instances -> #7f8c8d
# primary ciliary dyskinesia (Q1690779): 1 instances -> #7f8c8d
# dengue hemorrhagic fever (Q18554268): 1 instances -> #7f8c8d
# hypertension (Q95566669): 1 instances -> #7f8c8d
# esophageal neoplasm (Q56014520): 1 instances -> #7f8c8d
# gastrointestinal system cancer (Q5526839): 1 instances -> #7f8c8d
# diabetes (Q12206): 1 instances -> #7f8c8d
# obesity (Q12174): 1 instances -> #7f8c8d
# skin cancer (Q192102): 1 instances -> #7f8c8d
# cell type cancer (Q18553402): 1 instances -> #7f8c8d
# degenerative disorder of musculoskeletal system (Q100740636): 1 instances -> #7f8c8d
# bone disease (Q4941552): 1 instances -> #7f8c8d
# nutritional and metabolic diseases (Q55093063): 1 instances -> #7f8c8d
# lethal multiple congenital anomalies/dysmorphic syndrome (Q55788292): 1 instances -> #7f8c8d
# group of isomeric entities (Q15711994): 1 instances -> #7f8c8d
# pure substance (Q578779): 1 instances -> #7f8c8d
# chemical component (Q20026787): 1 instances -> #7f8c8d
# duodenal disease (Q18556187): 1 instances -> #7f8c8d
# ulcer (Q6452285): 1 instances -> #7f8c8d
# ion (Q36496): 1 instances -> #7f8c8d
# carbon oxoacid (Q72056948): 1 instances -> #7f8c8d
# organic acid (Q421948): 1 instances -> #7f8c8d
# carbonyl compound (Q9392635): 1 instances -> #7f8c8d
# convention (Q367293): 1 instances -> #7f8c8d
# bioactive compound use (Q124542283): 1 instances -> #7f8c8d
# lower respiratory tract infection (Q3631290): 1 instances -> #7f8c8d
# emphysema (Q1339243): 1 instances -> #7f8c8d
# respiratory system cancer (Q7315926): 1 instances -> #7f8c8d
# lung neoplasm (Q15124212): 1 instances -> #7f8c8d
# inflammatory bowel diseases (Q917447): 1 instances -> #7f8c8d
# primary bacterial infectious disease (Q18553247): 1 instances -> #7f8c8d
# mycobacterium infectious disease (Q4293079): 1 instances -> #7f8c8d
# endemic disease (Q506680): 1 instances -> #7f8c8d
# emerging communicable disease (Q609748): 1 instances -> #7f8c8d
# notifiable disease (Q314676): 1 instances -> #7f8c8d
# coronary artery disease (Q844935): 1 instances -> #7f8c8d
# ischemia (Q188151): 1 instances -> #7f8c8d
# infarction (Q207550): 1 instances -> #7f8c8d
# dispersion (Q178697): 1 instances -> #7f8c8d
# substance (Q10683158): 1 instances -> #7f8c8d
# environmental pollution (Q13065634): 1 instances -> #7f8c8d
# emission (Q105766508): 1 instances -> #7f8c8d
# type of pollution (Q129676813): 1 instances -> #7f8c8d
# physiological measure (Q108911336): 1 instances -> #7f8c8d
# ester (Q101487): 1 instances -> #7f8c8d
# Q105381234 (Q105381234): 1 instances -> #7f8c8d
# LSM-1535 (Q27163511): 1 instances -> #7f8c8d
# airborne transmission (Q11986959): 1 instances -> #7f8c8d
# service (Q7406919): 1 instances -> #7f8c8d
# maintenance (Q1043452): 1 instances -> #7f8c8d
# finding (Q37113105): 1 instances -> #7f8c8d
# pulmonary adventitious sound (Q43144253): 1 instances -> #7f8c8d
# Q98119401 (Q98119401): 1 instances -> #7f8c8d
# Q106589826 (Q106589826): 1 instances -> #7f8c8d
# landform (Q271669): 1 instances -> #7f8c8d
# natural physical object (Q16686022): 1 instances -> #7f8c8d
# natural geographic entity (Q27096220): 1 instances -> #7f8c8d
# astronomical body part (Q115385384): 1 instances -> #7f8c8d
# concrete object (Q4406616): 1 instances -> #7f8c8d
# Q336 (Q336): 1 instances -> #7f8c8d
# Q105948247 (Q105948247): 1 instances -> #7f8c8d
# Q110403031 (Q110403031): 1 instances -> #7f8c8d
# Q9081 (Q9081): 1 instances -> #7f8c8d
# Q26256810 (Q26256810): 1 instances -> #7f8c8d
# Q121344523 (Q121344523): 1 instances -> #7f8c8d
# Q2267705 (Q2267705): 1 instances -> #7f8c8d
# Q627436 (Q627436): 1 instances -> #7f8c8d
# Q4671286 (Q4671286): 1 instances -> #7f8c8d
# Q81976553 (Q81976553): 1 instances -> #7f8c8d
# Q419639 (Q419639): 1 instances -> #7f8c8d
# Q7886 (Q7886): 1 instances -> #7f8c8d
# Q28846466 (Q28846466): 1 instances -> #7f8c8d
# Q25449120 (Q25449120): 1 instances -> #7f8c8d
# Q113131469 (Q113131469): 1 instances -> #7f8c8d
# Q1339942 (Q1339942): 1 instances -> #7f8c8d
# Q21177113 (Q21177113): 1 instances -> #7f8c8d
# Q60539481 (Q60539481): 1 instances -> #7f8c8d
# Q42014143 (Q42014143): 1 instances -> #7f8c8d
# Q126034916 (Q126034916): 1 instances -> #7f8c8d
# Q47455774 (Q47455774): 1 instances -> #7f8c8d
# Q5780945 (Q5780945): 1 instances -> #7f8c8d
# Q160402 (Q160402): 1 instances -> #7f8c8d
# Q102186648 (Q102186648): 1 instances -> #7f8c8d
# Q75011544 (Q75011544): 1 instances -> #7f8c8d
# Q813912 (Q813912): 1 instances -> #7f8c8d
# Q130459448 (Q130459448): 1 instances -> #7f8c8d
# Q2141565 (Q2141565): 1 instances -> #7f8c8d
# Q122764215 (Q122764215): 1 instances -> #7f8c8d
# Q944806 (Q944806): 1 instances -> #7f8c8d
# Q1132455 (Q1132455): 1 instances -> #7f8c8d
# Q101208084 (Q101208084): 1 instances -> #7f8c8d
# Q1322005 (Q1322005): 1 instances -> #7f8c8d
# Q111752858 (Q111752858): 1 instances -> #7f8c8d
# Q15916540 (Q15916540): 1 instances -> #7f8c8d
# Q2145290 (Q2145290): 1 instances -> #7f8c8d
# Q1347367 (Q1347367): 1 instances -> #7f8c8d
# Q20203388 (Q20203388): 1 instances -> #7f8c8d
# Q714737 (Q714737): 1 instances -> #7f8c8d
# Q67518978 (Q67518978): 1 instances -> #7f8c8d
# Q2574811 (Q2574811): 1 instances -> #7f8c8d
# Q74948922 (Q74948922): 1 instances -> #7f8c8d
# Q29142 (Q29142): 1 instances -> #7f8c8d
# Q130583773 (Q130583773): 1 instances -> #7f8c8d
# Q4072473 (Q4072473): 1 instances -> #7f8c8d
# Q96634632 (Q96634632): 1 instances -> #7f8c8d
# Q5720030 (Q5720030): 1 instances -> #7f8c8d
# Q18603648 (Q18603648): 1 instances -> #7f8c8d
# Q31464082 (Q31464082): 1 instances -> #7f8c8d
# Q112234259 (Q112234259): 1 instances -> #7f8c8d
# Q5850078 (Q5850078): 1 instances -> #7f8c8d
# Q5127848 (Q5127848): 1 instances -> #7f8c8d
# Q126615441 (Q126615441): 1 instances -> #7f8c8d
# Q567709 (Q567709): 1 instances -> #7f8c8d
# Q100325978 (Q100325978): 1 instances -> #7f8c8d
# Q59627745 (Q59627745): 1 instances -> #7f8c8d
# Q44909815 (Q44909815): 1 instances -> #7f8c8d
# Q76852263 (Q76852263): 1 instances -> #7f8c8d
# Q59078 (Q59078): 1 instances -> #7f8c8d
# Q420457 (Q420457): 1 instances -> #7f8c8d
# Q1361144 (Q1361144): 1 instances -> #7f8c8d
# Q12167 (Q12167): 1 instances -> #7f8c8d
# Q37500013 (Q37500013): 1 instances -> #7f8c8d
# Q219858 (Q219858): 1 instances -> #7f8c8d
# Q97669203 (Q97669203): 1 instances -> #7f8c8d
# Q15710813 (Q15710813): 1 instances -> #7f8c8d
# Q55568967 (Q55568967): 1 instances -> #7f8c8d
# Q52086929 (Q52086929): 1 instances -> #7f8c8d
# Q109559114 (Q109559114): 1 instances -> #7f8c8d
# Q27163267 (Q27163267): 1 instances -> #7f8c8d
# Q27165305 (Q27165305): 1 instances -> #7f8c8d
# Q27122040 (Q27122040): 1 instances -> #7f8c8d
# Q18555947 (Q18555947): 1 instances -> #7f8c8d
# Q356033 (Q356033): 1 instances -> #7f8c8d
# Q18553442 (Q18553442): 1 instances -> #7f8c8d
# Q1414805 (Q1414805): 1 instances -> #7f8c8d
# Q55786852 (Q55786852): 1 instances -> #7f8c8d
# Q55789044 (Q55789044): 1 instances -> #7f8c8d
# Q55786280 (Q55786280): 1 instances -> #7f8c8d
# Q210588 (Q210588): 1 instances -> #7f8c8d
# Q7162 (Q7162): 1 instances -> #7f8c8d
# Q9418 (Q9418): 1 instances -> #7f8c8d
# Q131850943 (Q131850943): 1 instances -> #7f8c8d
# Q62577338 (Q62577338): 1 instances -> #7f8c8d
# psychiatry (Q7867): 1 instances -> #7f8c8d
# Q742487 (Q742487): 1 instances -> #7f8c8d
# Q109526510 (Q109526510): 1 instances -> #7f8c8d
# Q899851 (Q899851): 1 instances -> #7f8c8d
# Q2445303 (Q2445303): 1 instances -> #7f8c8d
# Q76722904 (Q76722904): 1 instances -> #7f8c8d
# methylphenidate (Q422112): 1 instances -> #7f8c8d
# Q59348943 (Q59348943): 1 instances -> #7f8c8d
# Q130705900 (Q130705900): 1 instances -> #7f8c8d
# Q12135 (Q12135): 1 instances -> #7f8c8d
# Q1641007 (Q1641007): 1 instances -> #7f8c8d
# Q6817451 (Q6817451): 1 instances -> #7f8c8d
# Q115870045 (Q115870045): 1 instances -> #7f8c8d
# Q2200417 (Q2200417): 1 instances -> #7f8c8d
# Q2393196 (Q2393196): 1 instances -> #7f8c8d
# Q3769299 (Q3769299): 1 instances -> #7f8c8d
# Q12046440 (Q12046440): 1 instances -> #7f8c8d
# Q188638 (Q188638): 1 instances -> #7f8c8d
# Q3221083 (Q3221083): 1 instances -> #7f8c8d
# Q54920211 (Q54920211): 1 instances -> #7f8c8d
# Q1755122 (Q1755122): 1 instances -> #7f8c8d
# Q1225194 (Q1225194): 1 instances -> #7f8c8d
# Q864601 (Q864601): 1 instances -> #7f8c8d
# Q1178507 (Q1178507): 1 instances -> #7f8c8d
# Q102187380 (Q102187380): 1 instances -> #7f8c8d
# Q684924 (Q684924): 1 instances -> #7f8c8d
# Q876887 (Q876887): 1 instances -> #7f8c8d
# Q27284588 (Q27284588): 1 instances -> #7f8c8d
# Q5958765 (Q5958765): 1 instances -> #7f8c8d
# Q3043160 (Q3043160): 1 instances -> #7f8c8d
# Q6806605 (Q6806605): 1 instances -> #7f8c8d
# Q55788795 (Q55788795): 1 instances -> #7f8c8d
# Q55785744 (Q55785744): 1 instances -> #7f8c8d
# Q55785828 (Q55785828): 1 instances -> #7f8c8d
# Q19834818 (Q19834818): 1 instances -> #7f8c8d
# Q17310777 (Q17310777): 1 instances -> #7f8c8d
# Q27165469 (Q27165469): 1 instances -> #7f8c8d
# Q27122242 (Q27122242): 1 instances -> #7f8c8d
# Q109545047 (Q109545047): 1 instances -> #7f8c8d
# Q408452 (Q408452): 1 instances -> #7f8c8d
# Q43305851 (Q43305851): 1 instances -> #7f8c8d
# Q2689559 (Q2689559): 1 instances -> #7f8c8d
# Q3360898 (Q3360898): 1 instances -> #7f8c8d
# Q3991665 (Q3991665): 1 instances -> #7f8c8d
# Q119526035 (Q119526035): 1 instances -> #7f8c8d
# Q126613991 (Q126613991): 1 instances -> #7f8c8d
# Q1924900 (Q1924900): 1 instances -> #7f8c8d
# Q186752 (Q186752): 1 instances -> #7f8c8d
# Q271449 (Q271449): 1 instances -> #7f8c8d
# Q585302 (Q585302): 1 instances -> #7f8c8d
# Q66561296 (Q66561296): 1 instances -> #7f8c8d
# Q109321311 (Q109321311): 1 instances -> #7f8c8d
# Q103914748 (Q103914748): 1 instances -> #7f8c8d
# Q539392 (Q539392): 1 instances -> #7f8c8d
# Q3347169 (Q3347169): 1 instances -> #7f8c8d
# Q3154357 (Q3154357): 1 instances -> #7f8c8d
# Q18554348 (Q18554348): 1 instances -> #7f8c8d
# Q18554228 (Q18554228): 1 instances -> #7f8c8d
# Q54926770 (Q54926770): 1 instances -> #7f8c8d
# Q41571 (Q41571): 1 instances -> #7f8c8d
# Q26998324 (Q26998324): 1 instances -> #7f8c8d
# Q911386 (Q911386): 1 instances -> #7f8c8d
# Q102186750 (Q102186750): 1 instances -> #7f8c8d
# Q18211751 (Q18211751): 1 instances -> #7f8c8d
# Q7300315 (Q7300315): 1 instances -> #7f8c8d
# Q780629 (Q780629): 1 instances -> #7f8c8d
# Q653197 (Q653197): 1 instances -> #7f8c8d
# Q18555950 (Q18555950): 1 instances -> #7f8c8d
# Q2971524 (Q2971524): 1 instances -> #7f8c8d
# Q12195125 (Q12195125): 1 instances -> #7f8c8d
# Q55789046 (Q55789046): 1 instances -> #7f8c8d
# Q145790 (Q145790): 1 instances -> #7f8c8d
# Q102186610 (Q102186610): 1 instances -> #7f8c8d
# Q102187028 (Q102187028): 1 instances -> #7f8c8d
# Q1451794 (Q1451794): 1 instances -> #7f8c8d
# Q2891709 (Q2891709): 1 instances -> #7f8c8d
# Q7204732 (Q7204732): 1 instances -> #7f8c8d
# Q5062122 (Q5062122): 1 instances -> #7f8c8d
# Q199615 (Q199615): 1 instances -> #7f8c8d
# Q12040808 (Q12040808): 1 instances -> #7f8c8d
# Q50808820 (Q50808820): 1 instances -> #7f8c8d
# Q18553502 (Q18553502): 1 instances -> #7f8c8d
# Q190805 (Q190805): 1 instances -> #7f8c8d
# Q18558062 (Q18558062): 1 instances -> #7f8c8d
# Q58490715 (Q58490715): 1 instances -> #7f8c8d
# Q104027169 (Q104027169): 1 instances -> #7f8c8d
# Q30336093 (Q30336093): 1 instances -> #7f8c8d
# Q188193 (Q188193): 1 instances -> #7f8c8d
# Q18554850 (Q18554850): 1 instances -> #7f8c8d
# Q3443277 (Q3443277): 1 instances -> #7f8c8d
# Q718675 (Q718675): 1 instances -> #7f8c8d
# Q2852249 (Q2852249): 1 instances -> #7f8c8d
# Q55789522 (Q55789522): 1 instances -> #7f8c8d
# Q1727229 (Q1727229): 1 instances -> #7f8c8d
# Q18558220 (Q18558220): 1 instances -> #7f8c8d
# Q779939 (Q779939): 1 instances -> #7f8c8d
# Q11461 (Q11461): 1 instances -> #7f8c8d
# Q203031 (Q203031): 1 instances -> #7f8c8d
# Q1928978 (Q1928978): 1 instances -> #7f8c8d
# Q19001421 (Q19001421): 1 instances -> #7f8c8d
# Q929451 (Q929451): 1 instances -> #7f8c8d
# Q6916469 (Q6916469): 1 instances -> #7f8c8d
# Q131345497 (Q131345497): 1 instances -> #7f8c8d
# Q54928607 (Q54928607): 1 instances -> #7f8c8d
# Q1064904 (Q1064904): 1 instances -> #7f8c8d
# Q5121708 (Q5121708): 1 instances -> #7f8c8d
# Q3259956 (Q3259956): 1 instances -> #7f8c8d
# Q27163380 (Q27163380): 1 instances -> #7f8c8d
# Q27167012 (Q27167012): 1 instances -> #7f8c8d
# Q81986228 (Q81986228): 1 instances -> #7f8c8d
# Q9255129 (Q9255129): 1 instances -> #7f8c8d
# Q426809 (Q426809): 1 instances -> #7f8c8d
# Q38881342 (Q38881342): 1 instances -> #7f8c8d
# Q816759 (Q816759): 1 instances -> #7f8c8d
# Q17504737 (Q17504737): 1 instances -> #7f8c8d
# Q27166230 (Q27166230): 1 instances -> #7f8c8d
# Q108196373 (Q108196373): 1 instances -> #7f8c8d
# Q27256299 (Q27256299): 1 instances -> #7f8c8d
# Q106040898 (Q106040898): 1 instances -> #7f8c8d
# Q604824 (Q604824): 1 instances -> #7f8c8d
# Q67593658 (Q67593658): 1 instances -> #7f8c8d
# Q27164730 (Q27164730): 1 instances -> #7f8c8d
# Q27165845 (Q27165845): 1 instances -> #7f8c8d
# Q420060 (Q420060): 1 instances -> #7f8c8d
# Q109614590 (Q109614590): 1 instances -> #7f8c8d
# Q2472771 (Q2472771): 1 instances -> #7f8c8d
# Q27163505 (Q27163505): 1 instances -> #7f8c8d
# Q1779868 (Q1779868): 1 instances -> #7f8c8d
# Q1346149 (Q1346149): 1 instances -> #7f8c8d
# Q56014516 (Q56014516): 1 instances -> #7f8c8d
# Q1216998 (Q1216998): 1 instances -> #7f8c8d
# Q5275615 (Q5275615): 1 instances -> #7f8c8d
# Q58833942 (Q58833942): 1 instances -> #7f8c8d
# Q108526292 (Q108526292): 1 instances -> #7f8c8d
# Q59662497 (Q59662497): 1 instances -> #7f8c8d
# Q103812529 (Q103812529): 1 instances -> #7f8c8d
# Q66545296 (Q66545296): 1 instances -> #7f8c8d
# Q4364110 (Q4364110): 1 instances -> #7f8c8d
# Q20089925 (Q20089925): 1 instances -> #7f8c8d
# Q119896085 (Q119896085): 1 instances -> #7f8c8d
# Q50429847 (Q50429847): 1 instances -> #7f8c8d
# Q427492 (Q427492): 1 instances -> #7f8c8d
# Q66587127 (Q66587127): 1 instances -> #7f8c8d
# Q20064627 (Q20064627): 1 instances -> #7f8c8d
# Q166774 (Q166774): 1 instances -> #7f8c8d
# Q474191 (Q474191): 1 instances -> #7f8c8d
# Q131908101 (Q131908101): 1 instances -> #7f8c8d
# Q6666023 (Q6666023): 1 instances -> #7f8c8d
# Q18556224 (Q18556224): 1 instances -> #7f8c8d
# Q18553586 (Q18553586): 1 instances -> #7f8c8d
# Q19000619 (Q19000619): 1 instances -> #7f8c8d
# Q584691 (Q584691): 1 instances -> #7f8c8d
# Q2565950 (Q2565950): 1 instances -> #7f8c8d
# Q63345803 (Q63345803): 1 instances -> #7f8c8d
# Q66615814 (Q66615814): 1 instances -> #7f8c8d
# Q18553679 (Q18553679): 1 instances -> #7f8c8d
# Q18921119 (Q18921119): 1 instances -> #7f8c8d
# Q343465 (Q343465): 1 instances -> #7f8c8d
# Q104401916 (Q104401916): 1 instances -> #7f8c8d
# Q27165454 (Q27165454): 1 instances -> #7f8c8d
# Q63088173 (Q63088173): 1 instances -> #7f8c8d
# Q24724533 (Q24724533): 1 instances -> #7f8c8d
# Q56440222 (Q56440222): 1 instances -> #7f8c8d
# Q82603006 (Q82603006): 1 instances -> #7f8c8d
# Q7689669 (Q7689669): 1 instances -> #7f8c8d
# Q99390198 (Q99390198): 1 instances -> #7f8c8d
# Q76505044 (Q76505044): 1 instances -> #7f8c8d
# Q24724548 (Q24724548): 1 instances -> #7f8c8d
# Q50209538 (Q50209538): 1 instances -> #7f8c8d
# Q954257 (Q954257): 1 instances -> #7f8c8d
# Q32907954 (Q32907954): 1 instances -> #7f8c8d
# Q414083 (Q414083): 1 instances -> #7f8c8d
# Q55788458 (Q55788458): 1 instances -> #7f8c8d
# Q19868531 (Q19868531): 1 instances -> #7f8c8d
# Q24027474 (Q24027474): 1 instances -> #7f8c8d
# Q55640599 (Q55640599): 1 instances -> #7f8c8d
# Q69092217 (Q69092217): 1 instances -> #7f8c8d
# Q49922434 (Q49922434): 1 instances -> #7f8c8d
# Q4291748 (Q4291748): 1 instances -> #7f8c8d
# Q1259977 (Q1259977): 1 instances -> #7f8c8d
# Q27163696 (Q27163696): 1 instances -> #7f8c8d
# Q1923741 (Q1923741): 1 instances -> #7f8c8d
# Q1310239 (Q1310239): 1 instances -> #7f8c8d
# Q409205 (Q409205): 1 instances -> #7f8c8d
# Q12034612 (Q12034612): 1 instances -> #7f8c8d
# Q10929058 (Q10929058): 1 instances -> #7f8c8d
# Q783794 (Q783794): 1 instances -> #7f8c8d
# Q4830453 (Q4830453): 1 instances -> #7f8c8d
# Q2852245 (Q2852245): 1 instances -> #7f8c8d
# Q3567921 (Q3567921): 1 instances -> #7f8c8d
# Q66824578 (Q66824578): 1 instances -> #7f8c8d
# Q4427704 (Q4427704): 1 instances -> #7f8c8d
# Q56810798 (Q56810798): 1 instances -> #7f8c8d
# Q421704 (Q421704): 1 instances -> #7f8c8d
# Q27163674 (Q27163674): 1 instances -> #7f8c8d
# Q73418929 (Q73418929): 1 instances -> #7f8c8d
# Q420401 (Q420401): 1 instances -> #7f8c8d
# Q65684228 (Q65684228): 1 instances -> #7f8c8d
# Q3241589 (Q3241589): 1 instances -> #7f8c8d
# Q8066 (Q8066): 1 instances -> #7f8c8d
# Q9150056 (Q9150056): 1 instances -> #7f8c8d
# Q425597 (Q425597): 1 instances -> #7f8c8d
# Q55524005 (Q55524005): 1 instances -> #7f8c8d
# Q72055753 (Q72055753): 1 instances -> #7f8c8d
# omeprazole (Q422210): 1 instances -> #7f8c8d
# Q65666252 (Q65666252): 1 instances -> #7f8c8d
# Q1747785 (Q1747785): 1 instances -> #7f8c8d
# Q581996 (Q581996): 1 instances -> #7f8c8d
# Q810254 (Q810254): 1 instances -> #7f8c8d
# Q3645517 (Q3645517): 1 instances -> #7f8c8d
# Q1214063 (Q1214063): 1 instances -> #7f8c8d
# vomiting (Q127076): 1 instances -> #7f8c8d
# Q587553 (Q587553): 1 instances -> #7f8c8d
# Q2393187 (Q2393187): 1 instances -> #7f8c8d
# Q126678011 (Q126678011): 1 instances -> #7f8c8d
# Q72508617 (Q72508617): 1 instances -> #7f8c8d
# Q126615236 (Q126615236): 1 instances -> #7f8c8d
# Q497173 (Q497173): 1 instances -> #7f8c8d
# Q2901852 (Q2901852): 1 instances -> #7f8c8d
# Q174211 (Q174211): 1 instances -> #7f8c8d
# Q11158 (Q11158): 1 instances -> #7f8c8d
# Q104637420 (Q104637420): 1 instances -> #7f8c8d
# Q192270 (Q192270): 1 instances -> #7f8c8d
# Q451967 (Q451967): 1 instances -> #7f8c8d
# Q754447 (Q754447): 1 instances -> #7f8c8d
# Q50377176 (Q50377176): 1 instances -> #7f8c8d
# Q804539 (Q804539): 1 instances -> #7f8c8d
# Q56256173 (Q56256173): 1 instances -> #7f8c8d
# Q40207875 (Q40207875): 1 instances -> #7f8c8d
# Q133981 (Q133981): 1 instances -> #7f8c8d
# Q6806542 (Q6806542): 1 instances -> #7f8c8d
# Q28742 (Q28742): 1 instances -> #7f8c8d
# Q422676 (Q422676): 1 instances -> #7f8c8d
# Q410897 (Q410897): 1 instances -> #7f8c8d
# Q28801726 (Q28801726): 1 instances -> #7f8c8d
# Q33127260 (Q33127260): 1 instances -> #7f8c8d
# Q56440659 (Q56440659): 1 instances -> #7f8c8d
# Q2425020 (Q2425020): 1 instances -> #7f8c8d
# Q44487897 (Q44487897): 1 instances -> #7f8c8d
# Q11516357 (Q11516357): 1 instances -> #7f8c8d
# Q100151658 (Q100151658): 1 instances -> #7f8c8d
# Q3776920 (Q3776920): 1 instances -> #7f8c8d
# Q42417296 (Q42417296): 1 instances -> #7f8c8d
# Q651223 (Q651223): 1 instances -> #7f8c8d
# Q4803677 (Q4803677): 1 instances -> #7f8c8d
# Q11432 (Q11432): 1 instances -> #7f8c8d
# Q21128838 (Q21128838): 1 instances -> #7f8c8d
# Q6746705 (Q6746705): 1 instances -> #7f8c8d
# Q47496130 (Q47496130): 1 instances -> #7f8c8d
# Q102186869 (Q102186869): 1 instances -> #7f8c8d
# Q27089148 (Q27089148): 1 instances -> #7f8c8d
# Q32039085 (Q32039085): 1 instances -> #7f8c8d
# Q50228773 (Q50228773): 1 instances -> #7f8c8d
# Q5572288 (Q5572288): 1 instances -> #7f8c8d
# Q431289 (Q431289): 1 instances -> #7f8c8d
# Q18928530 (Q18928530): 1 instances -> #7f8c8d
# Q2165411 (Q2165411): 1 instances -> #7f8c8d
# Q7578955 (Q7578955): 1 instances -> #7f8c8d
# Q6153637 (Q6153637): 1 instances -> #7f8c8d
# Q18621601 (Q18621601): 1 instances -> #7f8c8d
# Q7259546 (Q7259546): 1 instances -> #7f8c8d
# Q16662561 (Q16662561): 1 instances -> #7f8c8d
# Q27166297 (Q27166297): 1 instances -> #7f8c8d
# Q2853298 (Q2853298): 1 instances -> #7f8c8d
# Q30688752 (Q30688752): 1 instances -> #7f8c8d
# Q109393859 (Q109393859): 1 instances -> #7f8c8d
# Q935781 (Q935781): 1 instances -> #7f8c8d
# Q102187069 (Q102187069): 1 instances -> #7f8c8d
# Q66615932 (Q66615932): 1 instances -> #7f8c8d
# Q3968640 (Q3968640): 1 instances -> #7f8c8d
# Q10260689 (Q10260689): 1 instances -> #7f8c8d
# Q130313321 (Q130313321): 1 instances -> #7f8c8d
# Q100751718 (Q100751718): 1 instances -> #7f8c8d
# Q2383867 (Q2383867): 1 instances -> #7f8c8d
# Q63645073 (Q63645073): 1 instances -> #7f8c8d
# necrosis (Q178069): 1 instances -> #7f8c8d
# Q2751242 (Q2751242): 1 instances -> #7f8c8d
# Q126610343 (Q126610343): 1 instances -> #7f8c8d
# Q2750727 (Q2750727): 1 instances -> #7f8c8d
# Q3045009 (Q3045009): 1 instances -> #7f8c8d
# atenolol (Q411325): 1 instances -> #7f8c8d
# Q679692 (Q679692): 1 instances -> #7f8c8d
# Q11780457 (Q11780457): 1 instances -> #7f8c8d
# Q28555911 (Q28555911): 1 instances -> #7f8c8d
# Q752870 (Q752870): 1 instances -> #7f8c8d
# Q12060681 (Q12060681): 1 instances -> #7f8c8d
# Q1515493 (Q1515493): 1 instances -> #7f8c8d
# Q8065 (Q8065): 1 instances -> #7f8c8d
# Q29436423 (Q29436423): 1 instances -> #7f8c8d
# Q123349687 (Q123349687): 1 instances -> #7f8c8d
# Q168983 (Q168983): 1 instances -> #7f8c8d
# Q128650030 (Q128650030): 1 instances -> #7f8c8d
# Q1778613 (Q1778613): 1 instances -> #7f8c8d
# Q1751859 (Q1751859): 1 instances -> #7f8c8d
# Q19829510 (Q19829510): 1 instances -> #7f8c8d
# Q424418 (Q424418): 1 instances -> #7f8c8d
# Q60528603 (Q60528603): 1 instances -> #7f8c8d
# Q2144359 (Q2144359): 1 instances -> #7f8c8d
# Q1135789 (Q1135789): 1 instances -> #7f8c8d
# Q275372 (Q275372): 1 instances -> #7f8c8d
# Q214609 (Q214609): 1 instances -> #7f8c8d
# Q11398090 (Q11398090): 1 instances -> #7f8c8d
# Q79782 (Q79782): 1 instances -> #7f8c8d
# air pollution (Q131123): 1 instances -> #7f8c8d
# Q16332653 (Q16332653): 1 instances -> #7f8c8d
# Q208674 (Q208674): 1 instances -> #7f8c8d
# Q1150070 (Q1150070): 1 instances -> #7f8c8d
# Q1433212 (Q1433212): 1 instances -> #7f8c8d
# Q17004438 (Q17004438): 1 instances -> #7f8c8d
# Q113547463 (Q113547463): 1 instances -> #7f8c8d
# Q167198 (Q167198): 1 instances -> #7f8c8d
# Q2832080 (Q2832080): 1 instances -> #7f8c8d
# Q14864472 (Q14864472): 1 instances -> #7f8c8d
# Q66793652 (Q66793652): 1 instances -> #7f8c8d
# Q18554536 (Q18554536): 1 instances -> #7f8c8d
# Q102186674 (Q102186674): 1 instances -> #7f8c8d
# Q2622199 (Q2622199): 1 instances -> #7f8c8d
# nasopharyngitis (Q3936113): 1 instances -> #7f8c8d
# Q18975569 (Q18975569): 1 instances -> #7f8c8d
# Q55790495 (Q55790495): 1 instances -> #7f8c8d
# Q111527211 (Q111527211): 1 instances -> #7f8c8d
# bronchitis (Q173022): 1 instances -> #7f8c8d
# Q18557753 (Q18557753): 1 instances -> #7f8c8d
# Q18553248 (Q18553248): 1 instances -> #7f8c8d
# Q66773817 (Q66773817): 1 instances -> #7f8c8d
# Q18558167 (Q18558167): 1 instances -> #7f8c8d
# Q1920219 (Q1920219): 1 instances -> #7f8c8d
# Q83267 (Q83267): 1 instances -> #7f8c8d
# Q6823902 (Q6823902): 1 instances -> #7f8c8d
# Q4254955 (Q4254955): 1 instances -> #7f8c8d
# Q230855 (Q230855): 1 instances -> #7f8c8d
# Q2897903 (Q2897903): 1 instances -> #7f8c8d
# Q2424752 (Q2424752): 1 instances -> #7f8c8d
# Q8187769 (Q8187769): 1 instances -> #7f8c8d
# Q29028649 (Q29028649): 1 instances -> #7f8c8d
# Q3249551 (Q3249551): 1 instances -> #7f8c8d
# Q192581 (Q192581): 1 instances -> #7f8c8d
# Q2995644 (Q2995644): 1 instances -> #7f8c8d
# Q11028 (Q11028): 1 instances -> #7f8c8d
# Q15621286 (Q15621286): 1 instances -> #7f8c8d
# Q43143951 (Q43143951): 1 instances -> #7f8c8d
# Q99527517 (Q99527517): 1 instances -> #7f8c8d
# Q25894868 (Q25894868): 1 instances -> #7f8c8d
# Q12766313 (Q12766313): 1 instances -> #7f8c8d
# Q96253971 (Q96253971): 1 instances -> #7f8c8d
# Q223557 (Q223557): 1 instances -> #7f8c8d
# Q1970309 (Q1970309): 1 instances -> #7f8c8d
# Q115385481 (Q115385481): 1 instances -> #7f8c8d
# Q15989253 (Q15989253): 1 instances -> #7f8c8d
# Q123349660 (Q123349660): 1 instances -> #7f8c8d
# Q4373292 (Q4373292): 1 instances -> #7f8c8d
# Visualization saved to enhanced_asthma_knowledge_graph.html
# Number of nodes in visualization: 1974
# Number of edges in visualization: 7192
